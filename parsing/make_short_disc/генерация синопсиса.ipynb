# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

# %%
with open('/home/yc-user/EGOR_DONT_ENTER/WINK_hacaton/data/parsing/json/1 кейс Сценарии c Таблицами/Фишер (с таблицей)/1/ФИШЕР 3 сери __16.05.json', 'r') as f:
    data = json.load(f)

# %%
texts = []
for i in data:
    screen_text = i['text']
    texts.append(screen_text)

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         id                                              title  \
# 0      3-1       НАТ. МЯСОКОМБИНАТ.АВТОМОБИЛЬ НАРУЖКИ УТРО 7.
# 1      3-3       НАТ. МЯСОКОМБИНАТ.АВТОМОБИЛЬ НАРУЖКИ УТРО 7.
# 2      3-4       НАТ. МЯСОКОМБИНАТ.ФУРГОН ГАЧЕЧИЛАДЗЕ УТРО 7.
# 3    3-4-А                          НАТ. МЯСОКОМБИНАТ УТРО 7.
# 4      3-5                                НАТ. ДОРОГА УТРО 7.
# 5      3-6                                   НАТ. ЛЕС УТРО 7.
# 6    3-6-А                                   НАТ. ЛЕС УТРО 7.
# 7      3-7               ИНТ. КВАРТИРА КОЗЫРЕВА.КУХНЯ УТРО 7.
# 8      3-8  ИНТ. ОТДЕЛЕНИЕ МИЛИЦИИ ОДИНЦОВО.КАБИНЕТ СЛЕДОВ...
# 9      3-9    ИНТ. БОЛЬНИЦА ОДИНЦОВО.ДЕТСКАЯ. КОРИДОР УТРО 7.
# 10    3-10  ИНТ. ОТДЕЛЕНИЕ МИЛИЦИИ ОДИНЦОВО.КАБИНЕТ СЛЕДОВ...
# 11  3-10-А          ИНТ. ОТДЕЛЕНИЕ МИЛИЦИИ ОДИНЦОВО.КОРИДОР 6
# 12    3-11                   НАТ. ДЕТСКИЙ ДОМ.У ВОРОТ ДЕНЬ 7.
# 13    3-12              ИНТ. ДЕТСКИЙ ДОМ.ХОЛЛ КОРИДОР ДЕНЬ 7.
# ...

# %%
from synopsis_generator import SynopsisGenerator

# %%
a = SynopsisGenerator()

# %%
a.load_model()
# Out:
# Загрузка модели из /home/yc-user/EGOR_DONT_ENTER/models/avibe...
# Loading checkpoint shards: 100%|████████████████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.62it/s]
# Модель загружена успешно!

# %%
screen_texts = df['text'].values[:10]

# %%
# Генерация для одной сцены
# %time synopsis = a.generate_multiple_in_one_prompt(screen_texts)
# Out:
# CPU times: user 20.8 s, sys: 211 ms, total: 21.1 s
# Wall time: 21 s

# %%
df['synopsis'] = ''

# %%
df['synopsis'].iloc[:10] = synopsis
# Out:
# /tmp/ipykernel_187255/3801347944.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['synopsis'].iloc[:10] = synopsis

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
df[['id', 'title', 'synopsis']]
# Out:
#         id                                                         title  \
# 0      3-1                  НАТ. МЯСОКОМБИНАТ.АВТОМОБИЛЬ НАРУЖКИ УТРО 7.
# 1      3-3                  НАТ. МЯСОКОМБИНАТ.АВТОМОБИЛЬ НАРУЖКИ УТРО 7.
# 2      3-4                  НАТ. МЯСОКОМБИНАТ.ФУРГОН ГАЧЕЧИЛАДЗЕ УТРО 7.
# 3    3-4-А                                     НАТ. МЯСОКОМБИНАТ УТРО 7.
# 4      3-5                                           НАТ. ДОРОГА УТРО 7.
# 5      3-6                                              НАТ. ЛЕС УТРО 7.
# 6    3-6-А                                              НАТ. ЛЕС УТРО 7.
# 7      3-7                          ИНТ. КВАРТИРА КОЗЫРЕВА.КУХНЯ УТРО 7.
# 8      3-8  ИНТ. ОТДЕЛЕНИЕ МИЛИЦИИ ОДИНЦОВО.КАБИНЕТ СЛЕДОВАТЕЛЕЙ УТРО 7.
# 9      3-9               ИНТ. БОЛЬНИЦА ОДИНЦОВО.ДЕТСКАЯ. КОРИДОР УТРО 7.
# 10    3-10  ИНТ. ОТДЕЛЕНИЕ МИЛИЦИИ ОДИНЦОВО.КАБИНЕТ СЛЕДОВАТЕЛЕЙ ДЕНЬ 7.
# 11  3-10-А                     ИНТ. ОТДЕЛЕНИЕ МИЛИЦИИ ОДИНЦОВО.КОРИДОР 6
# ...

# %%
screen_texts[6]
# Out:
# '**ХВАН, БОКОВ, ГАЧЕЧИЛАДЗЕ, КИНОЛОГ****, каскадер-оперативник 2, немецкая овчарка**** (00:26)**\n\nСлужебная собака, взяв след из кабины, с бешеной скоростью уносится в чащу и вскоре заваливает Гачечиладзе, как и положено служебной собаке, поставив на него лапы и пуская слюну из огромной зубастой головы.\n\nВскоре появляются оперативники (Хван, Оперативник 1) и заковывают беглеца в наручники. Рубашка задралась, штаны съехали, лежит в позе морской звезды.\n\nБОКОВ\n\nГде Макурин?\n\nГАЧЕЧИЛАДЗЕ\n\nТудой!\n\nМашет рукой в противоположную сторону.'
